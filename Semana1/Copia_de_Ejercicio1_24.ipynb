# %% [markdown]
# <a href="https://colab.research.google.com/github/Davidperea99/DavidPerea/blob/main/Semana1/Copia_de_Ejercicio1_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller básico pandas - numpy

# %%
import pandas as pd

# %%
# Crear un dataframe que tenga 3 registros(filas) cada una debe contener el nombre de una cancion, el artista que la canta, y la duracion en segundos

# %%
nombre_Cancion= pd.Series(['Weekend','life','Enjoy'])
Artista = pd.Series(['Bumbury','Lenon','Elvis'])
Duracion_seg = pd.Series([1,2,3])

#print(nombre_Cancion)
#print(Artista)
#print(Duracion_seg)

df_songs = pd.DataFrame({'Nombre Cancion': nombre_Cancion, 'Artista': Artista, 'Duracion(s)': Duracion_seg})
df_songs
# Out:
#   Nombre Cancion  Artista  Duracion(s)
# 0        Weekend  Bumbury            1
# 1           life    Lenon            2
# 2          Enjoy    Elvis            3

# %%
# Imprimir la cola del dataframe
df_songs.tail()
# Out:
#   Nombre Cancion  Artista  Duracion(s)
# 0        Weekend  Bumbury            1
# 1           life    Lenon            2
# 2          Enjoy    Elvis            3

# %%
# Acceder a la columna duracion
df_songs['Duracion(s)']
# Out:
# 0    1
# 1    2
# 2    3
# Name: Duracion(s), dtype: int64

# %%
# Calcular el promedio de las duraciones
promedio = df_songs['Duracion(s)'].mean()
print(promedio)
# Out:
# 2.0

# %%
# Out:
#   Nombre Cancion  Artista  Duracion(s)
# 0        Weekend  Bumbury            1
# 1           life    Lenon            2
# 2          Enjoy    Elvis            3

# %%
# Obtener los nombres de las canciones que tengan duracion mayor que el promedio

df_songs['Duracion(s)'].apply(lambda T:T>promedio)

validacion = df_songs['Duracion(s)'].apply(lambda T:T>promedio)

##df_songs['Validacion'] = pd.Series(df_songs['Duracion(s)'].apply(lambda T:T>promedio))
df_songs['Nombre Cancion'][validacion == True]
# Out:
#   Nombre Cancion  Artista  Duracion(s)
# 0        Weekend  Bumbury            1
# 1           life    Lenon            2
# 2          Enjoy    Elvis            3

# %%
# Agregar una columna al dataframe que contenga True si la duracion es mayor que 3 minutos
# y false si es menor
df_songs['Validacion_T_or_F'] = pd.Series(df_songs['Duracion(s)'].apply(lambda T:T>promedio))
df_songs
# Out:
#   Nombre Cancion  Artista  Duracion(s)  Validacion_T_or_F
# 0        Weekend  Bumbury            1              False
# 1           life    Lenon            2              False
# 2          Enjoy    Elvis            3               True

# %%
# Convertir el dataframe a numpy array
import numpy  as np
array = df_songs.to_numpy()
array
# Out:
# array([['Weekend', 'Bumbury', 1, False],
#        ['life', 'Lenon', 2, False],
#        ['Enjoy', 'Elvis', 3, True]], dtype=object)

# %%
# Imprimir el shape del array
print(array.shape)
# Out:
# (3, 4)

# %%
# Hacer un reshape para convertir el arreglo de 3x3 a un arreglo de 12 elementos
arr_aux = array.reshape(12,)
arr_aux
# Out:
# array(['Weekend', 'Bumbury', 1, False, 'life', 'Lenon', 2, False, 'Enjoy',
#        'Elvis', 3, True], dtype=object)
